# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import stats
import data

import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
benchmark_ric = '.IDCOT7TR'
start_date = '2018-01-01'
end_date =  '2019-01-01'

benchmark_data = get_historical_pricing_data(benchmark_ric, start_date, end_date)
print(benchmark_data.columns)
# Out:
# Data access successful
# Index(['DATE', 'TRDPRC_1', 'OPEN_PRC', 'HIGH_1', 'LOW_1'], dtype='object')

# %%
benchmark_data['TRDPRC_1'].plot(figsize=(20, 5))

# %%
stats.get_roi(benchmark_data['TRDPRC_1'])
# Out:
# 3.6062

# %%
return_ = benchmark_data['TRDPRC_1'].diff().dropna()
return_.plot()

# %%
min(benchmark_data['TRDPRC_1'])
# Out:
# 99.2386

# %%
stats.get_max_draw_down(benchmark_data['TRDPRC_1'])
# Out:
# -6.273

# %%
(benchmark_data['TRDPRC_1'].pct_change()*100).describe()
# Out:
# count    498.000000
# mean       0.007463
# std        0.264652
# min       -0.804316
# 25%       -0.162843
# 50%        0.007942
# 75%        0.179954
# max        1.288588
# Name: TRDPRC_1, dtype: float64

# %%
stats.get_sharpe_ratio(benchmark_data['TRDPRC_1'])
# Out:
# 2.376507034608282

# %%
stats.print_full_statistics(benchmark_data['TRDPRC_1'])
# Out:
# ------------------------------
# Total % Return:        3.606%
# Total % Annual Return: 1.838%
# Maximum % Drawdown:    -6.273%
# Sharpe Ratio:          2.377%
# ------------------------------
